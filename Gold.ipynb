# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinu666/D--2F---212/blob/main/Gold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import plotly.express as px

# %%
 gold_df=pd.read_csv(url)
gold_df["Date"]=pd.to_datetime(gold_df["Date"])
df=gold_df(["Date","Close/Last"])
df=set_index("Date", inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = px.line(df, x="Date", y="Open")
df.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2004b5a5e682> in <cell line: 1>()
# ----> 1 df = px.line(df, x="Date", y="Open")
#       2 df.show()
#
# NameError: name 'px' is not defined

# %%
df.shape
# Out:
# (2539, 6)

# %%
df.describe()
# Out:
#         Close/Last         Volume         Open         High          Low
# count  2539.000000    2511.000000  2539.000000  2539.000000  2539.000000
# mean   1467.437456  183765.289128  1467.455967  1477.035880  1457.630721
# std     282.891621   98028.942525   283.126968   285.232942   280.366732
# min    1049.600000       1.000000  1051.500000  1062.700000  1045.400000
# 25%    1243.900000  123166.500000  1243.850000  1251.250000  1235.800000
# 50%    1321.400000  172127.000000  1321.700000  1329.300000  1314.000000
# 75%    1774.050000  233415.000000  1773.950000  1785.000000  1763.550000
# max    2069.400000  787217.000000  2076.400000  2085.400000  2049.000000

# %%
df.fillna(1915.2,inplace=True)

# %%
df
# Out:
#               Date  Close/Last    Volume    Open     Low
# High
# 1933.5  08/17/2023      1915.2  146770.0  1922.4  1914.2
# 1938.2  08/16/2023      1928.3  124766.0  1933.1  1922.0
# 1944.3  08/15/2023      1935.2  161512.0  1939.4  1927.5
# 1948.2  08/14/2023      1944.0  117514.0  1945.6  1934.2
# 1953.6  08/11/2023      1946.6  119090.0  1944.9  1942.7
# ...            ...         ...       ...     ...     ...
# 1399.9  08/23/2013      1395.8  149116.0  1376.1  1367.8
# 1381.4  08/22/2013      1370.8  134493.0  1365.6  1354.5
# 1378.9  08/21/2013      1370.1  137350.0  1371.0  1359.2
# 1378.0  08/20/2013      1372.6  130096.0  1364.9  1351.6
# 1384.1  08/19/2013      1365.7  116056.0  1377.1  1362.0
#
# [2539 rows x 5 columns]

# %%
df.count()
# Out:
# Date          2539
# Close/Last    2539
# Volume        2511
# Open          2539
# High          2539
# Low           2539
# dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#             Date  Close/Last    Volume    Open    High     Low
# 0     08/17/2023      1915.2  146770.0  1922.4  1933.5  1914.2
# 1     08/16/2023      1928.3  124766.0  1933.1  1938.2  1922.0
# 2     08/15/2023      1935.2  161512.0  1939.4  1944.3  1927.5
# 3     08/14/2023      1944.0  117514.0  1945.6  1948.2  1934.2
# 4     08/11/2023      1946.6  119090.0  1944.9  1953.6  1942.7
# ...          ...         ...       ...     ...     ...     ...
# 2534  08/23/2013      1395.8  149116.0  1376.1  1399.9  1367.8
# 2535  08/22/2013      1370.8  134493.0  1365.6  1381.4  1354.5
# 2536  08/21/2013      1370.1  137350.0  1371.0  1378.9  1359.2
# 2537  08/20/2013      1372.6  130096.0  1364.9  1378.0  1351.6
# 2538  08/19/2013      1365.7  116056.0  1377.1  1384.1  1362.0
#
# [2539 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 2539 entries, 1933.5 to 1384.1
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2539 non-null   object
#  1   Close/Last  2539 non-null   float64
#  2   Volume      2511 non-null   float64
#  3   Open        2539 non-null   float64
#  4   Low         2539 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 119.0+ KB

# %%
df.duplicated().values.any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['Date', 'Close/Last', 'Volume', 'Open', 'High', 'Low'], dtype='object')

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
file_id = "1-OtxDoa6gXFnYVFqHXl-0i0HINdtIcU2"
url="https://drive.google.com/uc?id={}".format(file_id)
df=pd.read_csv(url)
df
# Out:
#             Date  Close/Last    Volume    Open    High     Low
# 0     08/17/2023      1915.2  146770.0  1922.4  1933.5  1914.2
# 1     08/16/2023      1928.3  124766.0  1933.1  1938.2  1922.0
# 2     08/15/2023      1935.2  161512.0  1939.4  1944.3  1927.5
# 3     08/14/2023      1944.0  117514.0  1945.6  1948.2  1934.2
# 4     08/11/2023      1946.6  119090.0  1944.9  1953.6  1942.7
# ...          ...         ...       ...     ...     ...     ...
# 2534  08/23/2013      1395.8  149116.0  1376.1  1399.9  1367.8
# 2535  08/22/2013      1370.8  134493.0  1365.6  1381.4  1354.5
# 2536  08/21/2013      1370.1  137350.0  1371.0  1378.9  1359.2
# 2537  08/20/2013      1372.6  130096.0  1364.9  1378.0  1351.6
# 2538  08/19/2013      1365.7  116056.0  1377.1  1384.1  1362.0
#
# [2539 rows x 6 columns]

# %%
import pandas as pd
file_id = "13TeMqJEP4zX06LWauZtRnosp4k2Ybz6T"
url="https://drive.google.com/uc?id={}".format(file_id)
Sf=pd.read_csv(url)

# %%
Sf
# Out:
#       FNAME      LNAME          CELL                     EMAIL SALUTATION  \
# 0      John      Dodge  555-888-8888        jdodge@example.com        Mr.
# 1     Sarah      Smith  555-999-8888        ssnith@example.com        Ms.
# 2    George     Dapper  555-999-0000       gdapper@example.com        Dr.
# 3      Jack      Dodge  555-888-8888       jdodge2@example.com        Mr.
# 4   Jessica      Jones  555-999-8888        jjones@example.com       Mrs.
# 5    Dragon     Davich  555-999-0000       dragonr@example.com        Dr.
# 6     Steve      Curio  555-555-5454       curious@example.com        Mr.
# 7     Laura      Black  555-555-3434         black@example.com        Ms.
# 8   Wilhelm      Blake  555-555-5543        wblake@example.com        Mr.
# 9    Winter      Drake  555-555-5554       dragon2@example.com        Mr.
# 10      Sal      Sands  555-555-5553  sandssquared@example.com        Mr.
# 11    Julia      Wilds  555-555-9988        jwilds@example.com        Ms.
# ...

# %%
df[0:200:2]
# Out:
#            Date  Close/Last    Volume    Open    High     Low
# 0    08/17/2023      1915.2  146770.0  1922.4  1933.5  1914.2
# 2    08/15/2023      1935.2  161512.0  1939.4  1944.3  1927.5
# 4    08/11/2023      1946.6  119090.0  1944.9  1953.6  1942.7
# 6    08/09/2023      1950.6  130739.0  1959.3  1966.1  1947.2
# 8    08/07/2023      1970.0  101170.0  1977.6  1981.7  1966.1
# ..          ...         ...       ...     ...     ...     ...
# 190  11/11/2022      1774.2  182646.0  1758.3  1775.6  1750.3
# 192  11/09/2022      1715.8  221627.0  1715.2  1725.8  1705.1
# 194  11/07/2022      1680.5  170491.0  1678.6  1685.6  1670.0
# 196  11/03/2022      1637.7  241648.0  1639.1  1643.2  1618.3
# 198  11/01/2022      1636.4  193178.0  1636.1  1660.3  1633.6
#
# [100 rows x 6 columns]

# %%
df[0:10]['Date']
# Out:
# 0    08/17/2023
# 1    08/16/2023
# 2    08/15/2023
# 3    08/14/2023
# 4    08/11/2023
# 5    08/10/2023
# 6    08/09/2023
# 7    08/08/2023
# 8    08/07/2023
# 9    08/04/2023
# Name: Date, dtype: object

# %%
 df[0:10][['High','Low','Open']]
# Out:
#      High     Low    Open
# 0  1933.5  1914.2  1922.4
# 1  1938.2  1922.0  1933.1
# 2  1944.3  1927.5  1939.4
# 3  1948.2  1934.2  1945.6
# 4  1953.6  1942.7  1944.9
# 5  1963.5  1944.4  1947.7
# 6  1966.1  1947.2  1959.3
# 7  1972.8  1956.5  1971.5
# 8  1981.7  1966.1  1977.6
# 9  1945.0  1920.0  1934.9

# %%
df[['High','Low','Open','Date']][df.Open==df['Open'].max()]
# Out:
#        High     Low    Open        Date
# 761  2082.1  2024.8  2076.4  08/07/2020

# %%
rows
# Out:
# 2539

# %%
df.set_index('High',inplace=True)

# %%
df
# Out:
#               Date  Close/Last    Volume    Open     Low
# High
# 1933.5  08/17/2023      1915.2  146770.0  1922.4  1914.2
# 1938.2  08/16/2023      1928.3  124766.0  1933.1  1922.0
# 1944.3  08/15/2023      1935.2  161512.0  1939.4  1927.5
# 1948.2  08/14/2023      1944.0  117514.0  1945.6  1934.2
# 1953.6  08/11/2023      1946.6  119090.0  1944.9  1942.7
# ...            ...         ...       ...     ...     ...
# 1399.9  08/23/2013      1395.8  149116.0  1376.1  1367.8
# 1381.4  08/22/2013      1370.8  134493.0  1365.6  1354.5
# 1378.9  08/21/2013      1370.1  137350.0  1371.0  1359.2
# 1378.0  08/20/2013      1372.6  130096.0  1364.9  1351.6
# 1384.1  08/19/2013      1365.7  116056.0  1377.1  1362.0
#
# [2539 rows x 5 columns]

# %%
columns
# Out:
# 6

# %%
df.shape
# Out:
# (2539, 6)

# %%
df
# Out:
#             Date  Close/Last    Volume    Open    High     Low
# 0     08/17/2023      1915.2  146770.0  1922.4  1933.5  1914.2
# 1     08/16/2023      1928.3  124766.0  1933.1  1938.2  1922.0
# 2     08/15/2023      1935.2  161512.0  1939.4  1944.3  1927.5
# 3     08/14/2023      1944.0  117514.0  1945.6  1948.2  1934.2
# 4     08/11/2023      1946.6  119090.0  1944.9  1953.6  1942.7
# ...          ...         ...       ...     ...     ...     ...
# 2534  08/23/2013      1395.8  149116.0  1376.1  1399.9  1367.8
# 2535  08/22/2013      1370.8  134493.0  1365.6  1381.4  1354.5
# 2536  08/21/2013      1370.1  137350.0  1371.0  1378.9  1359.2
# 2537  08/20/2013      1372.6  130096.0  1364.9  1378.0  1351.6
# 2538  08/19/2013      1365.7  116056.0  1377.1  1384.1  1362.0
#
# [2539 rows x 6 columns]

# %%
df.head()
# Out:
#               Date  Close/Last    Volume    Open     Low
# High
# 1933.5  08/17/2023      1915.2  146770.0  1922.4  1914.2
# 1938.2  08/16/2023      1928.3  124766.0  1933.1  1922.0
# 1944.3  08/15/2023      1935.2  161512.0  1939.4  1927.5
# 1948.2  08/14/2023      1944.0  117514.0  1945.6  1934.2
# 1953.6  08/11/2023      1946.6  119090.0  1944.9  1942.7

# %%
df.tail()
# Out:
#               Date  Close/Last    Volume    Open     Low
# High
# 1399.9  08/23/2013      1395.8  149116.0  1376.1  1367.8
# 1381.4  08/22/2013      1370.8  134493.0  1365.6  1354.5
# 1378.9  08/21/2013      1370.1  137350.0  1371.0  1359.2
# 1378.0  08/20/2013      1372.6  130096.0  1364.9  1351.6
# 1384.1  08/19/2013      1365.7  116056.0  1377.1  1362.0

# %%
df.tail()
# Out:
#             Date  Close/Last    Volume    Open    High     Low
# 2534  08/23/2013      1395.8  149116.0  1376.1  1399.9  1367.8
# 2535  08/22/2013      1370.8  134493.0  1365.6  1381.4  1354.5
# 2536  08/21/2013      1370.1  137350.0  1371.0  1378.9  1359.2
# 2537  08/20/2013      1372.6  130096.0  1364.9  1378.0  1351.6
# 2538  08/19/2013      1365.7  116056.0  1377.1  1384.1  1362.0

# %%
df.head()
# Out:
#          Date  Close/Last    Volume    Open    High     Low
# 0  08/17/2023      1915.2  146770.0  1922.4  1933.5  1914.2
# 1  08/16/2023      1928.3  124766.0  1933.1  1938.2  1922.0
# 2  08/15/2023      1935.2  161512.0  1939.4  1944.3  1927.5
# 3  08/14/2023      1944.0  117514.0  1945.6  1948.2  1934.2
# 4  08/11/2023      1946.6  119090.0  1944.9  1953.6  1942.7

# %%
df.sample(10)
# Out:
#             Date  Close/Last    Volume    Open    High     Low
# 1244  09/07/2018      1200.4  272324.0  1205.6  1209.0  1198.7
# 1103  04/01/2019      1294.2  229896.0  1297.2  1301.7  1291.0
# 1565  05/31/2017      1275.4  193527.0  1265.7  1276.8  1262.0
# 1803  06/20/2016      1292.1  186003.0  1293.0  1296.8  1280.8
# 1844  04/21/2016      1250.3  261992.0  1244.5  1272.4  1244.4
# 1734  09/27/2016      1330.4  175693.0  1342.0  1343.5  1327.7
# 1828  05/13/2016      1272.7  167683.0  1264.8  1277.7  1264.0
# 1906  01/22/2016      1096.3  133883.0  1101.6  1103.5  1094.4
# 1099  04/05/2019      1295.6  227617.0  1296.5  1297.8  1288.3
# 2307  07/08/2014      1316.5  126706.0  1320.8  1325.7  1314.3

# %%
print(df["Date"][:15])
# Out:
# 0     08/17/2023
# 1     08/16/2023
# 2     08/15/2023
# 3     08/14/2023
# 4     08/11/2023
# 5     08/10/2023
# 6     08/09/2023
# 7     08/08/2023
# 8     08/07/2023
# 9     08/04/2023
# 10    08/03/2023
# 11    08/02/2023
# 12    08/01/2023
# 13    07/31/2023
# 14    07/28/2023
# Name: Date, dtype: object
